# %%
import pandas as pd
  
data = pd.read_csv('merged_output.csv')
# Out:
# C:\Users\Owner\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
solar_permits = data[data['CaseWorkclass'].str.contains('solar', case=False, na=False)]

# %%
solar_permits.head()
# Out:
#                                               CaseType  \
# 347            Building (Residential) - Solar - Ground
# 852  Electrical (Residential) - Solar Panel - Roof ...
# 866          Electrical (Residential) - Solar - Ground
# 885          Electrical (Residential) - Solar - Ground
# 886          Electrical (Residential) - Solar - Ground
#
#                             CaseWorkclass CaseStatus             IssueDate  \
# 347                   Solar - Ground/Roof  Withdrawn                   NaN
# 852  Solar Panel [Roof-Mounted] Expedited      Final  2022-04-28T18:36:23Z
# 866                   Solar [Ground/Roof]      Final  2022-04-25T12:20:57Z
# 885                   Solar [Ground/Roof]      Final  2022-04-20T14:52:18Z
# 886                   Solar [Ground/Roof]      Final  2022-04-28T13:27:18Z
#
#                     ApplyDate            ExpireDate             FinalDate  \
# 347  2022-03-07T19:29:20.277Z                   NaN                   NaN
# ...

# %%
solar_permits.shape
# Out:
# (637, 13)

# %%
solar_permits.to_csv('AA_505_solar_permits.csv')

# %%
# convert 'ApplyDate' 
solar_permits['ApplyDate'] = pd.to_datetime(solar_permits['ApplyDate'], errors='coerce')
solar_permits['Year'] = solar_permits['ApplyDate'].dt.year
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_27948\84959097.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_permits['ApplyDate'] = pd.to_datetime(solar_permits['ApplyDate'], errors='coerce')
# C:\Users\Owner\AppData\Local\Temp\ipykernel_27948\84959097.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_permits['Year'] = solar_permits['ApplyDate'].dt.year

# %%
# calculate per year and in total for solar
solar_per_year = filtered_data_solar['Year'].value_counts().sort_index()
total_solar = len(filtered_data_solar)

print("Occurrences of 'solar' per year:")
print(solar_per_year)
print("\nTotal occurrences of 'solar':", total_solar)

# %%
files = [
    'AA_solar_permits_Building_Commercial.csv',
    'AA_solar_permits_Electrical_Commercial.csv',
    ]

dataframes = []

for file in files:
    df = pd.read_csv(file)
    dataframes.append(df)

aa_permits_c = pd.concat(dataframes, ignore_index=True)

# %%
aa_permits_c.sample()
# Out:
#      Case Number                                         Type Status  \
# 22  BLDGC24-0238  Building (Commercial) - Solar - Ground/Roof  Final
#
#    Project Name Issued Date Applied Date Expiration Date Finalized Date  \
# 22          NaN  07/01/2024   06/05/2024      11/17/2025     05/15/2025
#
#    Module Name                             Address       Main Parcel  \
# 22      Permit  2111 Packard St Ann Arbor MI 48104  09-12-04-119-003
#
#                                           Description
# 22  Installation of (233) Solar Panels on the exis...

# %%
aa_permits.to_csv('AA_solar_permits_c.csv')

# %%
files = [
    'AA_solar_permits_Building_Residential_ground.csv',
    'AA_solar_permits_Electrical_Residential_ground.csv',
    'AA_solar_permits_Electrical_Residential_roof.csv',
    'AA_solar_permits_Electrical_Residential_roof (1).csv',
    'AA_solar_permits_Electrical_Residential_roof (2).csv',
    'AA_solar_permits_Electrical_Residential_roof (3).csv',
    'AA_solar_permits_Electrical_Residential_roof (4).csv',
    'AA_solar_permits_Electrical_Residential_roof (5).csv',
    'AA_solar_permits_Electrical_Residential_roof (6).csv',
    'AA_solar_permits_Electrical_Residential_roof (7).csv'
]

dataframes = []

for file in files:
    df = pd.read_csv(file)
    dataframes.append(df)

aa_permits_c = pd.concat(dataframes, ignore_index=True)

# %%
aa_permits.sample(5)
# Out:
#       Case Number                                               Type  \
# 850  ELECR25-2696  Electrical (Residential) - Solar Panel - Roof ...
# 110  ELECR24-3071          Electrical (Residential) - Solar - Ground
# 214  ELECR24-2093  Electrical (Residential) - Solar Panel - Roof ...
# 240  ELECR24-2749  Electrical (Residential) - Solar Panel - Roof ...
# 489  ELECR24-0598  Electrical (Residential) - Solar Panel - Roof ...
#
#                  Status Project Name Issued Date Applied Date Expiration Date  \
# 850  Submitted - Online          NaN         NaN   10/08/2025             NaN
# 110               Final          NaN  10/22/2024   10/04/2024      06/03/2025
# 214               Final          NaN  08/21/2024   07/10/2024      02/19/2025
# 240               Final          NaN  09/25/2024   09/09/2024      03/26/2025
# 489               Final          NaN  03/03/2024   02/21/2024      10/15/2024
#
#     Finalized Date Module Name                                  Address  \
# ...

# %%
aa_permits.to_csv('AA_solar_permits_r.csv')

# %%
# open saved csv
# convert dates to datetime for aggregation
# keep only Issued Date NOT null AND status == Final
